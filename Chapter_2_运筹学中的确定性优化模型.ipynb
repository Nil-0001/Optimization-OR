# %% [markdown]
# <a href="https://colab.research.google.com/github/Nil-0001/Optimization-OR/blob/main/Chapter_2_%E8%BF%90%E7%AD%B9%E5%AD%A6%E4%B8%AD%E7%9A%84%E7%A1%AE%E5%AE%9A%E6%80%A7%E4%BC%98%E5%8C%96%E6%A8%A1%E5%9E%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Chapter 2 运筹学中的确定性优化模型
#
# ### 假设所有关于问题的输入数据都是确定的
#
# ### 2.1 决策变量、约束条件及目标函数
#
# - 应用案例2-1 双原油问题
#
# - 2.1.1 决策变量
#
# - 2.1.2 变量类型约束
#
# - 2.1.3 主约束
#
# - 2.1.4 目标函数
#
# - 2.1.5 标准形式
#
# ### 2.2 图解法和最优化产出
#
# - 2.2.1 图解法
#
# - 2.2.2 可行域
#
# - 2.2.3 绘制约束及可行域
#
# - 2.2.4 绘制目标函数
#
# 	- 等值线
#
# 	- 最速下降方向
#
# - 2.2.5 最优解
#
# - 2.2.6 最优值
#
# - 2.2.7 唯一最优解与多个最优解
#
# - 2.2.8 不可行模型
#
# - 2.2.9 无界模型
#
# ### 2.3 大型优化模型及其标引
#
# - 2.3.1 标引
#
# - 2.3.2 标引决策变量
#
# - 2.3.3 标引符号参数
#
# - 2.3.4 目标函数
#
# - 2.3.5 标引约束条件族
#
# - 2.3.6 Pi Hybrids问题的优化模型
#
# - 2.3.7 模型规模如何变大
#
# ### 2.4 线性规划与非线性规划
#
# - 2.4.1 数学规划的一般形式
#
# - 2.4.2 右边项
#
# - 2.4.3 线性方程
#
# - 2.4.4 定义线性与非线性规划
#
# - 2.4.5 E-MART问题
#
# - 2.4.6 E-MART问题的标引、参数与决策变量
#
# - 2.4.7 非线性响应
#
# - 2.4.8 E-MART问题的优化模型
#
# ### 2.5 离散（或者整数）规划
#
# - 应用案例2-4 伯利恒钢锭模
#
# - 2.5.1 伯利恒问题的标引及参数
#
# - 2.5.2 离散决策变量vs.连续决策变量
#
# - 2.5.3 包含离散变量的约束
#
# - 2.5.4 伯利恒问题的优化模型
#
# - 2.5.5 整数规划与混合整数规划
#
# - 2.5.6 整数线性规划vs.整数非线性规划
#
# - 应用案例2-5 普渡大学期末考试安排
#
# - 2.5.7 普渡大学期末考试安排问题的标引、参数与决策变量
#
# - 2.5.8 非线性目标函数
#
# - 2.5.9 普渡大学期末考试安排问题的优化模型
#
# ### 2.6 多目标优化模型
#
# - 应用案例2-6 杜佩琪土地使用规划
#
# - 2.6.1 多目标
#
# - 2.6.2 杜佩琪土地使用规划问题的约束条件
#
# - 2.6.3 杜佩琪土地使用规划问题的优化模型
#
# - 2.6.4 目标函数之间的冲突
#
# ### 2.7 优化模型分类小结
#
# ### 2.8 计算机求解技术以及AMPL
#
# - 2.8.1 求解程序与建模语言
#
# - 2.8.2 标引、求和以及符号参数
#
# - 2.8.3 非线性规划模型与整数规划模型
