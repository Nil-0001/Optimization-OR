# %% [markdown]
# <a href="https://colab.research.google.com/github/Nil-0001/Optimization-OR/blob/main/Chapter_11_%E7%A6%BB%E6%95%A3%E4%BC%98%E5%8C%96%E6%A8%A1%E5%9E%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Chapter 11 离散优化模型
#
# ### 11.1 块状/批量线性规划及固定成本
#
# - 11.1.1 全或无约束下的瑞典钢铁实例
#
# - 11.1.2 全或无条件下的整数线性规划模型
#
# - 11.1.3 全或无约束下的瑞典钢铁模型
#
# - 11.1.4 固定成本的整数线性规划建模
#
# - 11.1.5 含有固定成本的瑞典钢铁实例
#
# ### 11.2 背包模型与资本预算模型
#
# - 11.2.1 背包问题
#
# - 11.2.2 资产预算模型
#
# - 11.2.3 预算约束
#
# - 11.2.4 互斥选择模型
#
# - 11.2.5 项目间依赖关系建模
#
# - 11.2.6 NASA实例模型
#
# ### 11.3 集合包装、覆盖和划分模型
#
# - 11.3.1 集合包装、覆盖和划分约束条件
#
# - 11.3.2 EMS模型的最小覆盖
#
# - 11.3.3 EMS模型的最大覆盖
#
# - 11.3.4 列生成模型
#
# - 11.3.5 AA实例的列生产模型
#
# ### 11.4 分配模型及匹配模型
#
# - 11.4.1 分配约束
#
# - 11.4.2 计算机辅助制造（CAM）的线性分配实例回顾
#
# - 11.4.3 线性分配模型
#
# - 11.4.4 二次分配模型
#
# - 11.4.5 购物商城布局实例的模型
#
# - 11.4.6 广义分配模型
#
# - 11.4.7 CDOT实例模型
#
# - 11.4.8 匹配模型
#
# - 11.4.9 Superfi实例模型
#
# - 11.4.10 分配模型和匹配模型的可处理性
#
# ### 11.5 旅行商和路径模型
#
# - 11.5.1 旅行商问题
#
# - 11.5.2 旅行商问题的对称与不对称形式
#
# - 11.5.3 对称旅行商问题的建模
#
# - 11.5.4 子路径问题
#
# - 11.5.5 对称旅行商问题的整数线性规划模型
#
# - 11.5.6 不对称旅行商问题的整数线性规划模型
#
# - 11.5.7 旅行商问题中的二次分配建模
#
# - 11.5.8 需要求解多个路径的问题
#
# - 11.5.9 KI货运路径应用模型
#
# ### 11.6 设施选址和网络设计模型
#
# - 11.6.1 设施选址模型
#
# - 11.6.2 设施选址的整数线性规划模型
#
# - 11.6.3 Tmark设施选址实例模型
#
# - 11.6.4 网络设计模型
#
# - 11.6.5 废水网络设计实例模型
#
# ### 11.7 处理机调度及排序模型
#
# - 11.7.1 单处理机调度问题
#
# - 11.7.2 时间决策变量
#
# - 11.7.3 冲突约束和分离变量
#
# - 11.7.4 对截止日期的处理
#
# - 11.7.5 处理机调度问题的目标函数
#
# - 11.7.6 建立最小最大值调度目标下的整数线性规划
#
# - 11.7.7 调度目标函数之间的等价
#
# - 11.7.8 作业车间调度问题
#
# - 11.7.9 定制金属加工实例的决策变量和目标函数
#
# - 11.7.10 优先约束
#
# - 11.7.11 作业车间调度的冲突约束
#
# - 11.7.12 定制金属加工的实例模型
