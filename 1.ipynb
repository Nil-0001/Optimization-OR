# %% [markdown]
# <a href="https://colab.research.google.com/github/Nil-0001/Optimization/blob/main/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Optimization in Operations Research
#
# **胡运权**
# - 01 线性规划与单纯形法
# - 02 对偶理论和灵敏度分析
# - 03 运输问题
# - 04 线性目标规划
# - 05 整数线性规划
# - 06 网络计划
# - 07 图与网络优化*
# - 08 动态规划
# - 09 排队论*
# - 10 存储论*
# - 11 博弈论(对策论)*
# - 12 决策论(单目标决策)#
# - 13 无约束问题(非线性规划)*
# - 14 约束极值问题(非线性规划)*
# - 15 多目标决策*
# - 16 启发式方法*
#
# **Ronald L. Rardin**
# - Chapter 1 运用数学模型解决问题
# - Chapter 2 运筹学中的确定性优化模型
# - Chapter 3 搜索算法
# - Chapter 4 线性规划
# - Chapter 5 线性规划的单纯形法
# - Chapter 6 线性规划的对偶理论与灵敏度分析
# - Chapter 7 线性规划内点法
# - Chapter 8 目标规划
# - Chapter 9 最短路与离散动态规划
# - Chapter 10 网络流与图
# - Chapter 11 离散优化模型
# - Chapter 12 离散优化求解方法
# - Chapter 13 大规模优化方法
# - Chapter 14 计算复杂性理论
# - Chapter 15 离散优化的启发式算法
# - Chapter 16 无约束的非线性规划
# - Chapter 17 带约束的非线性规划
#
# ## Chapter 1 运用数学模型解决问题
#
# ### 数学模型是什么？运筹学OR是什么？
#
# ### 1.1 运筹学应用案例
#
# - 应用案例1-1 Mortimer Middleman
#
# ### 1.2 优化及运筹学方法的步骤
#
# - 建模、分析、推论、评价
#
# - 1.2.1 决策、约束与目标
#
# - 1.2.2 优化与数学规划
#
# - 1.2.3  常数需求率假设
#
# - 1.2.4 粗略分析
#
# - 1.2.5 常数需求率模型
#
# - 1.2.6 可行解与最优解
#
# ### 1.3 系统边界、敏感性分析、易处理性以及有效性
#
# - 1.3.1 常数需求率下的EOQ模型
#
# - 1.3.2 系统边界与敏感性分析
#
# - 1.3.3 解析解
#
# - 1.3.4 易处理性与有效性
#
# ### 1.4 描述性模型与仿真模拟
#
# - 1.4.1 MM历史数据仿真
#
# - 1.4.2 仿真模型的有效性
#
# - 1.4.3 描述性模型与规范性模型
#
# ### 1.5 数值搜索，精确解与启发解
#
# - 1.5.1 数值搜索
#
# - 1.5.2 不同搜索起点
#
# - 1.5.3  精确优化与启发优化
#
# ### 1.6 确定模型与随机模型
#
# - 1.6.1 随机变量及其实现
#
# - 1.6.2 随机仿真
#
# - 1.6.3 确定模型与随机模型之间的权衡
#
# ### 运筹模型需要考虑哪些问题？
#
# ## Chapter 2 运筹学中的确定性优化模型
#
# ### 假设所有关于问题的输入数据都是确定的
#
# ### 2.1 决策变量、约束条件及目标函数
#
# - 应用案例2-1 双原油问题
#
# - 2.1.1 决策变量
#
# - 2.1.2 变量类型约束
#
# - 2.1.3 主约束
#
# - 2.1.4 目标函数
#
# - 2.1.5 标准形式
#
# ### 2.2 图解法和最优化产出
#
# - 2.2.1 图解法
#
# - 2.2.2 可行域
#
# - 2.2.3 绘制约束及可行域
#
# - 2.2.4 绘制目标函数
#
# 	- 等值线
#
# 	- 最速下降方向
#
# - 2.2.5 最优解
#
# - 2.2.6 最优值
#
# - 2.2.7 唯一最优解与多个最优解
#
# - 2.2.8 不可行模型
#
# - 2.2.9 无界模型
#
# ### 2.3 大型优化模型及其标引
#
# - 2.3.1 标引
#
# - 2.3.2 标引决策变量
#
# - 2.3.3 标引符号参数
#
# - 2.3.4 目标函数
#
# - 2.3.5 标引约束条件族
#
# - 2.3.6 Pi Hybrids问题的优化模型
#
# - 2.3.7 模型规模如何变大
#
# ### 2.4 线性规划与非线性规划
#
# - 2.4.1 数学规划的一般形式
#
# - 2.4.2 右边项
#
# - 2.4.3 线性方程
#
# - 2.4.4 定义线性与非线性规划
#
# - 2.4.5 E-MART问题
#
# - 2.4.6 E-MART问题的标引、参数与决策变量
#
# - 2.4.7 非线性响应
#
# - 2.4.8 E-MART问题的优化模型
#
# ### 2.5 离散（或者整数）规划
#
# - 应用案例2-4 伯利恒钢锭模
#
# - 2.5.1 伯利恒问题的标引及参数
#
# - 2.5.2 离散决策变量vs.连续决策变量
#
# - 2.5.3 包含离散变量的约束
#
# - 2.5.4 伯利恒问题的优化模型
#
# - 2.5.5 整数规划与混合整数规划
#
# - 2.5.6 整数线性规划vs.整数非线性规划
#
# - 应用案例2-5 普渡大学期末考试安排
#
# - 2.5.7 普渡大学期末考试安排问题的标引、参数与决策变量
#
# - 2.5.8 非线性目标函数
#
# - 2.5.9 普渡大学期末考试安排问题的优化模型
#
# ### 2.6 多目标优化模型
#
# - 应用案例2-6 杜佩琪土地使用规划
#
# - 2.6.1 多目标
#
# - 2.6.2 杜佩琪土地使用规划问题的约束条件
#
# - 2.6.3 杜佩琪土地使用规划问题的优化模型
#
# - 2.6.4 目标函数之间的冲突
#
# ### 2.7 优化模型分类小结
#
# ### 2.8 计算机求解技术以及AMPL
#
# - 2.8.1 求解程序与建模语言
#
# - 2.8.2 标引、求和以及符号参数
#
# - 2.8.3 非线性规划模型与整数规划模型
#
# ## Chapter 3 搜索算法
#
# ### 3.1 搜索算法、局部和全局最优
#
# - 3.1.1 解
#
# - 3.1.2 解的向量形式
#
# - 3.1.3 搜索算法实例
#
# - 3.1.4 邻域视角
#
# - 3.1.5 局部最优
#
# - 3.1.6 局部最优和搜索算法
#
# - 3.1.7 局部和全局最优
#
# - 3.1.8 局部最优的处理
#
# ### 3.2 沿可行改进方向的搜索
#
# - 3.2.1 方向步长范式
#
# - 3.2.2 可行方向
#
# - 3.2.3 如何确定步长
#
# - 3.2.4 DClub搜索
#
# - 3.2.5 搜索算法何时停止
#
# - 3.2.6 检验无界性
#
# ### 3.3 可行该进方向的代数条件
#
# - 3.3.1 梯度
#
# - 3.3.2 改进方向的梯度条件
#
# - 3.3.3 将目标函数梯度作为搜索方向
#
# - 3.3.4 起作用约束和可行方向
#
# - 3.3.5 线性约束
#
# - 3.3.6 线性约束下可行方向的代数条件
#
# ### 3.4 线性目标和凸集的易处理性
#
# - 3.4.1 线性目标函数的易处理性
#
# - 3.4.2 约束条件和局部最优
#
# - 3.4.3 凸集
#
# - 3.4.4 连线的代数表示
#
# - 3.4.5 凸集的易处理性
#
# - 3.4.6 凸集和线性目标的全局最优性
#
# - 3.4.7 线性约束可行集的凸性
#
# - 3.4.8 线性规划搜索算法的全局最优性
#
# - 3.4.9 线性规划的阻碍约束
#
# ### 3.5 寻找初始可行解
#
# - 3.5.1 两阶段法
#
# - 3.5.2 再次审视双原油模型
#
# - 3.5.3 人工变量
#
# - 3.5.4 第一阶段模型
#
# - 3.5.5 从人工初始解开始
#
# - 3.5.6 第一阶段结果
#
# - 3.5.7 由第一阶段得到原模型无可行解
#
# - 3.5.8 大M法
#
# - 3.5.9 大M法的搜索结果
#
# ## Chapter 4 线性规划
#
# ### 4.1 资源分配模型
#
# - 应用案例4-1 林务局的分配问题
#
# - 4.1.1 林务局分配问题中的决策变量
#
# - 4.1.2 林务局分配模型
#
# ### 4.2 混料模型
#
# - 应用案例4-2 瑞典钢材生产
#
# - 4.2.1 混料模型的决策变量
#
# - 4.2.2 成分约束
#
# - 4.2.3 瑞典钢材生产模型
#
# - 4.2.4 比率约束
#
# ### 4.3 运营规划模型
#
# - 应用案例4-3 管材产品运营规划
#
# - 4.3.1 管材产品运营规划模型
#
# - 应用案例4-4 加拿大森林产品有限公司（CFPL）运营规划
#
# - 4.3.2 CFPL模型的决策变量
#
# - 4.3.3 连续变量表示整数量
#
# - 4.3.4 CFPL的目标函数
#
# - 4.3.5 CFPL的约束
#
# - 4.3.6 平衡约束
#
# - 4.3.7 CFPL线性规划模型
#
# ### 4.4 排班和人员规划模型
#
# - 应用案例4-5 俄亥俄国家银行排班规划
#
# - 4.4.1 ONB的决策变量和目标函数
#
# - 4.4.2 ONB的约束条件
#
# - 4.4.3 覆盖约束
#
# - 4.4.4 ONB排班模型
#
# ### 4.5 多阶段模型
#
# - 应用案例4-6 食品服务机构的现金流管理
#
# - 4.5.1 多阶段模型的决策变量
#
# - 4.5.2 多阶段的平衡约束
#
# - 4.5.3 IFS的现金流模型
#
# - 4.5.4 时间区间
#
# ### 4.6 可行性化的非线性目标模型
#
# - 应用案例4-7 高速公路巡逻队
#
# - 4.6.1 最大化总和的高速公路巡逻模型
#
# - 4.6.2 极小化极大和极大化极小目标函数
#
# - 4.6.3 非线性的极大化极小高速公路巡逻队模型
#
# - 4.6.4 线性化极小化极大和极大化极小目标函数
#
# - 4.6.5 极大化极小高速公路巡逻队模型的线性化变换
#
# - 应用案例4-8 VP公司的选址问题
#
# - 4.6.6 非线性VP选址模型
#
# - 4.6.7 最小化偏差式的目标函数
#
# - 4.6.8 最小偏差目标函数的线性化变换
#
# - 4.6.9 VP选址模型的线性化变换
#
# ### 4.7 随机规划
#
# - 应用案例4-9 快速救援
#
# - 4.7.1 QA例子的确定模型
#
# - 4.7.2 带偿付随机规划
#
# - 4.7.3 QA应用的随机规划模型
#
# - 4.7.4 一般形式和大规模处理技术
#
# ## Chapter 5 线性规划的单纯形法
#
# ### 5.1 线性规划的最优解和标准型
#
# - 应用案例5-1 高级黄铜奖杯
#
# - 5.1.1 线性规划的全局最优解
#
# - 5.1.2 内点、边界点和顶点
#
# - 5.1.3 线性规划的最优解
#
# - 5.1.4 LP标准型
#
# - 5.1.5 用松弛变量将不等化为非负
#
# - 5.1.6 将非正和无符号要求的变量转化为非负
#
# - 5.1.7 线性规划的标准符号表示
#
# ### 5.2 顶点搜索和基本解
#
# - 5.2.1 用紧约束来确定顶点
#
# - 5.2.2 相邻的顶点和边
#
# - 5.2.3 基本解
#
# - 5.2.4 基本解的存在性
#
# - 5.2.5 基本可行解和顶点
#
# ### 5.3 单纯形法
#
# - 5.3.1 标准表示法
#
# - 5.3.2 初始基本解
#
# - 5.3.3 单纯形方向
#
# - 5.3.4 优化单纯形方向与成本减少
#
# - 5.3.5 步长和比值最小法则
#
# - 5.3.6 换基
#
# - 5.3.7 初级单纯形法
#
# - 5.3.8 用初级单纯形法求解高级黄铜奖杯问题
#
# - 5.3.9 停止搜索与全局最优
#
# - 5.3.10 顶点或极方向
#
# ### 5.4 字典和单纯形表
#
# - 5.4.1 单纯形字典
#
# - 5.4.2 单纯形表
#
# - 5.4.3 使用字典或单纯性表的单纯形法
#
# - 5.4.4 与优化搜索模式的关联
#
# - 5.4.5 两种形式的比较
#
# ### 5.5 两阶段法
#
# - 5.5.1 两阶段单纯形法的初始基
#
# - 5.5.2 线性规划的三种可能结果
#
# - 5.5.3 克莱德案例无可行解的情况
#
# - 5.5.4 克莱德案例有最优解的情况
#
# - 5.5.5 克莱德案例无界的情况
#
# ### 5.6 退化与零步长
#
# - 5.6.1 退化解
#
# - 5.6.2 零步长
#
# - 5.6.3 换基改进
#
# ### 5.7 单纯形法的收敛和循环
#
# - 5.7.1 步长为正的有限收敛
#
# - 5.7.2 退化与循环
#
# ### 5.8 力求高效：修正单纯形法
#
# - 5.8.1 用基的逆矩阵计算
#
# - 5.8.2 更新B-1
#
# - 5.8.3 修正单纯形法中基变量的顺序
#
# - 5.8.4 用定价计算成本减少
#
# - 5.8.5 高级黄铜奖杯的修正单纯形法
#
# ### 5.9 有简单上下限的单纯形法
#
# - 5.9.1 有上下限的标准型
#
# - 5.9.2 有上下限的基本解
#
# - 5.9.3 无上下限且无符号要求的变量
#
# - 5.9.4 非基变量值的增减
#
# - 5.9.5 增减值求步长
#
# - 5.9.6 不换基的情况
#
# - 5.9.7 有上下限的单纯形法
#
# - 5.9.8 用有上下限的单纯形法解高级黄铜奖杯问题
#
# ## Chapter 6 线性规划的对偶理论与灵敏度分析
#
# ### 6.1 通用的活动视角与资源视角
#
# - 6.1.1 以成本和收益度量的目标函数
#
# - 6.1.2 选择不等式约束条件的方向
#
# - 6.1.3 资源供应与需求的不等式约束
#
# - 6.1.4 供应与需求的等式约束
#
# - 6.1.5 变量类型约束
#
# - 6.1.6 活动视角的变量
#
# - 6.1.7 表示活动投入与产出的不等号左端系数
#
# ### 6.2 对线性规划模型系数变化的定性灵敏度分析
#
# - 6.2.1 松约束与紧约束
#
# - 6.2.2 重读“瑞典钢铁生产”案例
#
# - 6.2.3 不等号右端系数（RHS）变化的影响
#
# - 6.2.4 不等号左端系数（LHS）变化的影响
#
# - 6.2.5 增加或删减约束的影响
#
# - 6.2.6 其他约束的影响
#
# - 6.2.7 系数约束对结果影响的变化率
#
# - 6.2.8 目标函数系数变化的影响
#
# - 6.2.9 目标函数系数对结果影响的变化率
#
# - 6.2.10 增添或删减变量的影响
#
# ### 6.3 线性规划模型系数灵敏度的定量分析：对偶模型
#
# - 6.3.1 原始以及对偶模型的定义
#
# - 6.3.2 对偶变量
#
# - 6.3.3 对偶变量类型
#
# - 6.3.4 再读双原油模型案例
#
# - 6.3.5 对偶变量隐含含义：资源边际价格
#
# - 6.3.6 从资源生产和消费视角看生产活动的隐含价格
#
# - 6.3.7 主对偶约束：生产活动价格
#
# - 6.3.8 原始和对偶问题的最优值相等关系
#
# - 6.3.9 原始约束条件与对偶变量值的互补松弛特性
#
# - 6.3.10 对偶约束条件和原始变量的对偶互补松弛特性
#
# ### 6.4 构造线性规划的对偶问题
#
# - 6.4.1 非负原始变量的对偶形式
#
# - 6.4.2 变量非正以及符号任意的原始LP模型对应的对偶问题
#
# - 6.4.3 对偶问题的对偶问题是原问题
#
# ### 6.5 计算机输出结果与单个参数变化的影响
#
# - 6.5.1 CFPL案例的原始问题和对偶问题
#
# - 6.5.2 约束灵敏度输出结果
#
# - 6.5.3 不等号右端系数变化范围
#
# - 6.5.4 约束条件变动的影响
#
# - 6.5.5 灵敏度变量输出
#
# - 6.5.6 目标系数范围
#
# - 6.5.7 变动变量的影响
#
# - 6.5.8 增加或删减约束条件的影响
#
# - 6.5.9 增删变量的影响
#
# ### 6.6 模型大幅度改动，再优化以及参数规划
#
# - 6.6.1 RHS和目标系数范围限制的模糊性
#
# - 6.6.2 斜率变化和退化之间的关系
#
# - 6.6.3 使灵敏度准确的再优化
#
# - 6.6.4 单个系数的参数变化
#
# - 6.6.5 评估多参量变化的影响
#
# - 6.6.6 多参量RHS变化
#
# - 6.6.7 多目标函数系数变化的影响
#
# ### 6.7 线性规划中的对偶问题和最优解
#
# - 6.7.1 对偶问题的对偶问题
#
# - 6.7.2 目标值的弱对偶性
#
# - 6.7.3 无界及无解情形
#
# - 6.7.4 互补松弛性及最优解
#
# - 6.7.5 线性规划中的强对偶条件与KKT最优化条件
#
# - 6.7.6 标准形式下的模型
#
# - 6.7.7 基于基本分段框架的标准线性规划形式
#
# - 6.7.8 分段形式下的基本解
#
# - 6.7.9 互补对偶基本解
#
# - 6.7.10 原始单纯形法最优与KKT条件的必要性
#
# ### 6.8 对偶单纯形法的搜索
#
# - 6.8.1 选择优化方向
#
# - 6.8.2 确定对偶步长以保持对偶解可行性
#
# - 6.8.3 改变原始解以及基的更新
#
# ### 6.9 原始—对偶单纯形法搜索
#
# - 6.9.1 选择优化对偶的方向
#
# - 6.9.2 决定对偶步长
#
# ## Chapter 7 线性规划内点法
#
# ### 7.1 在可行域内部搜索
#
# - 7.1.1 内点
#
# - 7.1.2 通过目标函数确定移动方向
#
# - 7.1.3 内点法的边界策略
#
# - 7.1.4 线性规划（LP）标准型的内点
#
# - 7.1.5 投影方法处理等式约束
#
# - 7.1.6 沿投影方向改进
#
# ### 7.2 对当前解进行尺度变化
#
# - 7.2.1 仿射尺度变换
#
# - 7.2.2 仿射尺度变换的对角矩阵建立
#
# - 7.2.3 仿射尺度变换后的标准型
#
# - 7.2.4 向仿射尺度变换后的等式约束投影
#
# - 7.2.5 内点法的计算代价
#
# ### 7.3 仿射尺度变换搜索
#
# - 7.3.1 仿射尺度变换移动方向
#
# - 7.3.2 仿射尺度变换移动方向的可行性与是否改进
#
# - 7.3.3 仿射尺度变换的步长
#
# - 7.3.4 仿射尺度变换搜索停止
#
# - 7.3.5 仿射尺度变换搜索在弗兰妮木柴问题中的应用
#
# ### 7.4 内点搜索的对数障碍法
#
# - 7.4.1 障碍目标函数
#
# - 7.4.2 梯度方向问题
#
# - 7.4.3 障碍法中的牛顿步
#
# - 7.4.4 牛顿步障碍法的步长
#
# - 7.4.5 障碍因子λ的影响
#
# - 7.4.6 障碍因子策略
#
# - 7.4.7 牛顿步障碍算法
#
# - 7.4.8 弗兰妮木柴问题的牛顿障碍解
#
# ### 7.5 原始对偶内点法
#
# - 7.5.1 KKT最优性条件
#
# - 7.5.2 原始对偶内点法策略
#
# - 7.5.3 可行移动方向
#
# - 7.5.4 互补松弛性的管理
#
# - 7.5.5 步长
#
# - 7.5.6 求解移动方向条件
#
# ### 7.6 线性规划搜索算法的复杂性
#
# - 7.6.1 线性规划实例的输入长度
#
# - 7.6.2 线性规划单纯形法的复杂性
#
# - 7.6.3 线性规划内点法的复杂性
#
# ## Chapter 8 目标规划
#
# ### 8.1 多目标优化模型
#
# - 8.1.1 银行投资目标
#
# - 8.1.2 银行投资模型
#
# - 8.1.3 测功机环设计模型
#
# - 8.1.4 危险废料处理模型
#
# ### 8.2 有效点和有效边界
#
# - 8.2.1 有效点
#
# - 8.2.2 图像法确定有效点
#
# - 8.2.3 有效边界
#
# - 8.2.4 目标函数值图像
#
# - 8.2.5 构造有效边界
#
# ### 8.3 抢占式优化和加权目标
#
# - 8.3.1 抢占式优化
#
# - 8.3.2 抢占式优化银行投资
#
# - 8.3.3 抢占式优化和有效点
#
# - 8.3.4 抢占式优化和可替代最优解
#
# - 8.3.5 加权目标
#
# - 8.3.6 危险废料处理的加权优化
#
# - 8.3.7 加权优化和有效点
#
# ### 8.4 目标规划
#
# - 8.4.1 目标或目标水平
#
# - 8.4.2 银行投资的目标形式
#
# - 8.4.3 软约束
#
# - 8.4.4 偏差变量
#
# - 8.4.5 用一般数学形式表示软约束
#
# - 8.4.6 目标规划的目标函数：最小化（加权）偏差量
#
# - 8.4.7 银行投资的线性目标规划
#
# - 8.4.8 目标函数的可选偏差权重
#
# - 8.4.9 抢占式目标规划
#
# - 8.4.10 银行投资的抢占式目标规划
#
# - 8.4.11 抢占式目标规划的加权法
#
# - 8.4.12 多目标问题中目标规划的实用性
#
# - 8.4.13 目标规划和有效点
#
# - 8.4.14 优化目标规划模型以保证有效点
#
# ## Chapter 9 最短路与离散动态规划
#
# ### 9.1 最短路模型
#
# - 9.1.1 节点、弧、边、图
#
# - 9.1.2 路
#
# - 9.1.3 最短路问题
#
# - 9.1.4 最短路模型的分类
#
# - 9.1.5 无向图和有向图
#
# - 9.1.6 “双环”马戏团案例模型
#
# ### 9.2 利用动态规划解决最短路问题
#
# - 9.2.1 最短路模型族
#
# - 9.2.2 函数符号
#
# - 9.2.3 最优路径和子路
#
# - 9.2.4 反例：负权环路
#
# - 9.2.5 最优性原理
#
# - 9.2.6 函数方程
#
# - 9.2.7 从一个节点到所有其他节点的函数方程
#
# - 9.2.8 一个起点到其他节点（一对多）的函数方程的充分性
#
# - 9.2.9 从所有节点到所有其他节点（多对多）的函数方程
#
# - 9.2.10 利用线性规划解决最短路问题
#
# ### 9.3 一对多的最短路问题：贝尔曼—福特算法
#
# - 9.3.1 函数方程的求解
#
# - 9.3.2 重复评价算法：贝尔曼—福特算法
#
# - 9.3.3 使用贝尔曼—福特算法解决“双环”马戏团的案例
#
# - 9.3.4 贝尔曼—福特算法的原理
#
# - 9.3.5 找到最优路径
#
# - 9.3.6 负权环路下的贝尔曼—福特算法
#
# ### 9.4 多对多最短路问题：弗洛伊德—瓦尔肖算法
#
# - 9.4.1 弗洛伊德—瓦尔肖算法
#
# - 9.4.2 利用弗洛伊德—瓦尔肖算法解决利特维尔案例
#
# - 9.4.3 找到最优路径
#
# - 9.4.4 负权环路下的弗洛伊德—瓦尔肖算法
#
# ### 9.5 无负权一对多最短路问题：迪杰斯特拉算法
#
# - 9.5.1 临时和永久标签的节点
#
# - 9.5.2 永久标签节点的选取
#
# - 9.5.3 利用迪杰斯特拉算法解决德克萨斯运输公司问题
#
# - 9.5.4 复原最短路径
#
# - 9.5.5 迪杰斯特拉算法原理
#
# ### 9.6 一对多无环图最短路问题
#
# - 9.6.1 无环图
#
# - 9.6.2 无环有向图的最短路算法
#
# - 9.6.3 无环最短路例子
#
# - 9.6.4 最长路问题与无环有向图
#
# ### 9.7 CPM项目计划和最长路
#
# - 9.7.1 项目管理
#
# - 9.7.2 CPM项目网络
#
# - 9.7.3 CPM计划和最长路
#
# - 9.7.4 关键路径
#
# - 9.7.5 计算WeBuild建筑公司的最早开工时间计划表
#
# - 9.7.6 最晚开始时间表和计划时差
#
# - 9.7.7 项目网络的无环特征
#
# ### 9.8 离散动态规划模型
#
# - 9.8.1 序贯决策问题
#
# - 9.8.2 动态规划中的状态
#
# - 9.8.3 动态规划的有向图
#
# - 9.8.4 最优路径的动态规划解法
#
# - 9.8.5 动态规划函数方程
#
# - 9.8.6 拥有阶段（stage）和状态（state）的动态规划模型
#
# - 9.8.7 总统图书馆案例的动态规划建模
#
# - 9.8.8 动态规划的逆推解法
#
# - 9.8.9 同时获得多个问题的解
#
# ### 9.9 利用动态规划解决整数规划问题
#
# ### 9.10 马尔科夫决策过程
#
# - 9.10.1 MDP模型的基本要素
#
# - 9.10.2 乳腺癌MDP的解
#
# ## Chapter 10 网络流与图
#
# ### 10.1 图、网络与流
#
# - 10.1.1 有向图、节点与弧
#
# - 10.1.2 OOI应用网络
#
# - 10.1.3 最小费用流模型
#
# - 10.1.4 源、汇及转运节点
#
# - 10.1.5 OOI应用模型
#
# - 10.1.6 总供给=总需求
#
# - 10.1.7 初始可行解
#
# - 10.1.8 人工网络流模型
#
# - 10.1.9 时间扩展流模型及网络
#
# - 10.1.10 对阿格力科应用的时间扩展建模
#
# - 10.1.11 节点—弧关联矩阵及矩阵标准形式
#
# ### 10.2 用于网络流搜索的圈方向
#
# - 10.2.1 链、路、圈与回路
#
# - 10.2.2 圈方向
#
# - 10.2.3 利用圈方向保持流平衡
#
# - 10.2.4 可行圈方向
#
# - 10.2.5 改进圈方向
#
# - 10.2.6 沿圈方向的步长
#
# - 10.2.7 圈方向的充分性
#
# - 10.2.8 网络流的退化圈方向搜索
#
# - 10.2.9 OOI应用的退化圈方向搜索
#
# ### 10.3 消圈算法求最优流
#
# - 10.3.1 残留有向图
#
# - 10.3.2 残留有向图的可行圈方向及回路
#
# - 10.3.3 残留有向图的可行改进方向及负回路
#
# - 10.3.4 利用最短路径算法寻找圈方向
#
# - 10.3.5 OOI应用的消圈解
#
# - 10.3.6 消圈的多项式计算规则
#
# ### 10.4 网络单纯形法求最优流
#
# - 10.4.1 节点—弧矩阵及圈中的线性相关性
#
# - 10.4.2 网络的生成树
#
# - 10.4.3 网络流模型的生成树基
#
# - 10.4.4 网络基解
#
# - 10.4.5 单纯圈方向
#
# - 10.4.6 网络单纯形法
#
# - 10.4.7 OOI应用的网络单纯解
#
# ### 10.5 最优网络流的整性
#
# - 10.5.1 最优网络流何时一定为整数
#
# - 10.5.2 节点—弧关联矩阵的全幺模性
#
# ### 10.6 运输及分配模型
#
# - 10.6.1 运输问题
#
# - 10.6.2 运输问题的标准形式
#
# - 10.6.3 分配问题
#
# - 10.6.4 用伪元素平衡不等集合
#
# - 10.6.5 分配问题的整数网络流解
#
# - 10.6.6 CAM分配应用模型
#
# ### 10.7 用匈牙利算法求解分配问题
#
# - 10.7.1 原始—对偶策略与初始对偶解
#
# - 10.7.2 相等子图
#
# - 10.7.3 利用标记在相等子图中搜索原始解
#
# - 10.7.4 对偶值更新与修正后的相等子图
#
# - 10.7.5 沿交错路的解扩张
#
# - 10.7.6 匈牙利算法的计算规则
#
# ### 10.8 最大流与最小割
#
# - 10.8.1 可行改进圈方向与流增广路
#
# - 10.8.2 最大流最小割算法
#
# - 10.8.3 用算法10E求解图10-25a的最大流应用
#
# - 10.8.4 最大流及最小割值的等价关系
#
# - 10.8.5 算法10E的计算规则
#
# ### 10.9 多商品及增益/损耗流
#
# - 10.9.1 多商品流
#
# - 10.9.2 多商品流模型
#
# - 10.9.3 多商品流模型的易处理性
#
# - 10.9.4 带增益及损耗的流
#
# - 10.9.5 增益及损耗网络流模型
#
# - 10.9.6 带增益及损耗的网络流的易处理性
#
# ### 10.10 最小/最大生成树
#
# - 10.10.1 最小/最大生成树与贪心算法
#
# - 10.10.2 用贪心算法10F求解应用案例10-8
#
# - 10.10.3 用组合树表示贪心结果
#
# - 10.10.4 生成树问题的整数线性规划公式
#
# - 10.10.5 贪心算法的计算规则
#
# ## Chapter 11 离散优化模型
#
# ### 11.1 块状/批量线性规划及固定成本
#
# - 11.1.1 全或无约束下的瑞典钢铁实例
#
# - 11.1.2 全或无条件下的整数线性规划模型
#
# - 11.1.3 全或无约束下的瑞典钢铁模型
#
# - 11.1.4 固定成本的整数线性规划建模
#
# - 11.1.5 含有固定成本的瑞典钢铁实例
#
# ### 11.2 背包模型与资本预算模型
#
# - 11.2.1 背包问题
#
# - 11.2.2 资产预算模型
#
# - 11.2.3 预算约束
#
# - 11.2.4 互斥选择模型
#
# - 11.2.5 项目间依赖关系建模
#
# - 11.2.6 NASA实例模型
#
# ### 11.3 集合包装、覆盖和划分模型
#
# - 11.3.1 集合包装、覆盖和划分约束条件
#
# - 11.3.2 EMS模型的最小覆盖
#
# - 11.3.3 EMS模型的最大覆盖
#
# - 11.3.4 列生成模型
#
# - 11.3.5 AA实例的列生产模型
#
# ### 11.4 分配模型及匹配模型
#
# - 11.4.1 分配约束
#
# - 11.4.2 计算机辅助制造（CAM）的线性分配实例回顾
#
# - 11.4.3 线性分配模型
#
# - 11.4.4 二次分配模型
#
# - 11.4.5 购物商城布局实例的模型
#
# - 11.4.6 广义分配模型
#
# - 11.4.7 CDOT实例模型
#
# - 11.4.8 匹配模型
#
# - 11.4.9 Superfi实例模型
#
# - 11.4.10 分配模型和匹配模型的可处理性
#
# ### 11.5 旅行商和路径模型
#
# - 11.5.1 旅行商问题
#
# - 11.5.2 旅行商问题的对称与不对称形式
#
# - 11.5.3 对称旅行商问题的建模
#
# - 11.5.4 子路径问题
#
# - 11.5.5 对称旅行商问题的整数线性规划模型
#
# - 11.5.6 不对称旅行商问题的整数线性规划模型
#
# - 11.5.7 旅行商问题中的二次分配建模
#
# - 11.5.8 需要求解多个路径的问题
#
# - 11.5.9 KI货运路径应用模型
#
# ### 11.6 设施选址和网络设计模型
#
# - 11.6.1 设施选址模型
#
# - 11.6.2 设施选址的整数线性规划模型
#
# - 11.6.3 Tmark设施选址实例模型
#
# - 11.6.4 网络设计模型
#
# - 11.6.5 废水网络设计实例模型
#
# ### 11.7 处理机调度及排序模型
#
# - 11.7.1 单处理机调度问题
#
# - 11.7.2 时间决策变量
#
# - 11.7.3 冲突约束和分离变量
#
# - 11.7.4 对截止日期的处理
#
# - 11.7.5 处理机调度问题的目标函数
#
# - 11.7.6 建立最小最大值调度目标下的整数线性规划
#
# - 11.7.7 调度目标函数之间的等价
#
# - 11.7.8 作业车间调度问题
#
# - 11.7.9 定制金属加工实例的决策变量和目标函数
#
# - 11.7.10 优先约束
#
# - 11.7.11 作业车间调度的冲突约束
#
# - 11.7.12 定制金属加工的实例模型
#
# ## Chapter 12 离散优化求解方法
#
# ### 12.1 全枚举法求解
#
# - 12.1.1 全枚举法
#
# - 12.1.2 瑞士钢铁“全或无”案例应用
#
# - 12.1.3 枚举情况的指数增长
#
# ### 12.2 离散优化模型的松弛模型及其应用
#
# - 12.2.1 约束条件的松弛
#
# - 12.2.2 线性规划松弛
#
# - 12.2.3 修改目标函数的松弛模型
#
# - 12.2.4 用松弛模型证明不可行性
#
# - 12.2.5 松弛给出的最优目标值界限
#
# - 12.2.6 利用松弛模型得到最优解
#
# - 12.2.7 松弛模型的取整解
#
# - 12.2.8 更强的线性规划松弛模型
#
# - 12.2.9 选择大M常量
#
# ### 12.3 分支定界搜索
#
# - 12.3.1 部分解
#
# - 12.3.2 部分解的完全形式
#
# - 12.3.3 树搜索
#
# - 12.3.4 最佳解
#
# - 12.3.5 候选问题
#
# - 12.3.6 通过松弛模型终止部分解
#
# - 12.3.7 基于线性规划的分支定界法
#
# - 12.3.8 基于线性规划的分支定界法的分支规则
#
# - 12.3.9 用基于线性规划的分支定界法求解河流能源公司应用
#
# ### 12.4 分支定界法的改良
#
# - 12.4.1 应用分支定界法求解NASA资本预算案例
#
# - 12.4.2 最佳解整数化
#
# - 12.4.3 分支定界系谱图中的术语
#
# - 12.4.4 母节点界限
#
# - 12.4.5 利用母节点界限终止
#
# - 12.4.6 提前停止：分支定界作为一种启发式算法
#
# - 12.4.7 用最佳解停止搜索所产生的误差界限
#
# - 12.4.8 深度优先顺序，最优优先顺序，深度向前最优回溯顺序
#
# ### 12.5 分支切割法
#
# - 12.5.1 有效不等式
#
# - 12.5.2 分支切割搜索
#
# - 12.5.3 用分支切割法求解河流能源公司应用
#
# ### 12.6 有效不等式组
#
# - 12.6.1 高莫利割平面（纯整数模型）
#
# - 12.6.2 高莫利混合整数割平面
#
# - 12.6.3 特定模型的有效不等式组
#
# ### 12.7 割平面理论
#
# - 12.7.1 整数可行解的凸包
#
# - 12.7.2 线性规划与凸包
#
# - 12.7.3 有效不等式的面、侧面和类别
#
# - 12.7.4 侧面对应的有效不等式的仿射独立特征
#
# - 12.7.5 非满维的凸包和有效等式
#
# ## Chapter 13 大规模优化方法
#
# ### 13.1 列生成算法和分支定价算法
#
# - 13.1.1 适合使用列生产算法的问题
#
# - 13.1.2 限制主问题
#
# - 13.1.3 列生产算法的一般步骤
#
# - 13.1.4 算法13A在应用案例13-1中的应用
#
# - 13.1.5 生成满足条件的列
#
# - 13.1.6 分支定价算法
#
# ### 13.2 拉格朗日松弛算法
#
# - 13.2.1 拉格朗日松弛
#
# - 13.2.2 易处理的拉格朗日松弛方法
#
# - 13.2.3 拉格朗日松弛问题的界和最优解
#
# - 13.2.4 拉格朗日对偶问题
#
# - 13.2.5 拉格朗日对偶问题和线性松弛问题确定的上下界
#
# - 13.2.6 拉格朗日对偶问题的目标函数
#
# - 13.2.7 求解拉格朗日界的次梯度优化算法
#
# - 13.2.8 次梯度搜索算法应用举例
#
# ### 13.3 Dantzing-Wolfe分解算法
#
# - 13.3.1 根据极点和极方向重新建模
#
# - 13.3.2 对应用案例13-4中GB公司最优化问题重新建模
#
# - 13.3.3 子问题极点和极方向的生成方法
#
# - 13.3.4 应用Dantzig-Wolfe分解算法求解应用案例13-4
#
# ### 13.4 Benders分解算法
#
# - 13.4.1 Benders分解策略
#
# - 13.4.2 Benders分解算法13E的最优性原理
#
# - 13.4.3 应用Benders分解算法13E求解应用案例13-5
#
# ## Chapter 14 计算复杂性理论
#
# ### 14.1 问题、实例和求解的难度
#
# ### 14.2 衡量算法复杂性及问题的难度
#
# - 14.2.1 计算的时间复杂度
#
# - 14.2.2 基于编码输入长度的实例规模
#
# - 14.2.3 优化问题实例的编码长度表示
#
# ### 14.3 可解问题的多项式时间验证标准
#
# ### 14.4 多项式可解和非确定多项式可解
#
# - 14.4.1 判定问题和最优化问题
#
# - 14.4.2 P问题—多项式时间可解的判定问题
#
# - 14.4.3 NP问题—非确定多项式时间可解判定问题
#
# - 14.4.4 多项式时间可解问题类和非确定多项式时间可解问题类
#
# ### 14.5 多项式时间归约和NP难问题
#
# - 14.5.1 问题之间的多项式时间归约
#
# - 14.5.2 NP完全问题和NP难问题
#
# ### 14.6 P问题和NP问题
#
# ### 14.7 求解NP难问题
#
# - 14.7.1 特例
#
# - 14.7.2 伪多项式时间算法
#
# - 14.7.3 平均计算性能
#
# - 14.7.4 分支定界算法和分支切割算法中更强的松弛问题和割
#
# - 14.7.5 带有最优目标函数上下界的启发式算法
#
# - 14.7.6 求解一般问题的启发式/近似算法
#
# ## Chapter 15 离散优化的启发式算法
#
# ### 15.1 构造型启发式算法
#
# - 15.1.1 基础构造型搜索算法
#
# - 15.1.2 变量固定的贪婪选择
#
# - 15.1.3 NASA应用中的贪婪规则
#
# - 15.1.4 NTSE应用的构造型启发式解
#
# - 15.1.5 构造型搜索的需求
#
# - 15.1.6 KI卡车路线应用的构造型搜索
#
# ### 15.2 针对离散优化INLPs问题改进搜索启发式算法
#
# - 15.2.1 基础改进搜索算法
#
# - 15.2.2 离散邻域和移动集合
#
# - 15.2.3 NCB应用的回顾
#
# - 15.2.4 选择一个移动集合
#
# - 15.2.5 NCB应用的基础改进搜索
#
# - 15.2.6 多起点搜索
#
# ### 15.3 元启发式算法：禁忌搜索和模拟退火
#
# - 15.3.1 允许非改进移动的难点
#
# - 15.3.2 禁忌搜索
#
# - 15.3.3 NCB应用的禁忌搜索
#
# - 15.3.4 模拟退火搜索
#
# - 15.3.5 NCB应用的模拟退火搜索
#
# ### 15.4 进化元启发式算法和遗传算法
#
# - 15.4.1 遗传算法的交配操作
#
# - 15.4.2 遗传算法的精英、移民、突变和交叉
#
# - 15.4.3 遗传算法搜索的解编码
#
# - 15.4.4 NCB应用的遗传算法搜索
#
# ## Chapter 16 无约束的非线性规划
#
# ### 16.1 无约束非线性规划模型
#
# - 16.1.1 USPS单变量应用模型
#
# - 16.1.2 忽略约束以应用无约束方法
#
# - 16.1.3 曲线拟合和回归问题
#
# - 16.1.4 线性和非线性回归
#
# - 16.1.5 回归的目标函数
#
# - 16.1.6 定制计算机公司曲线拟合的应用模型
#
# - 16.1.7 极大似然估计
#
# - 16.1.8 PERT极大似然估计的应用模型
#
# - 16.1.9 平滑与非平滑函数和导数
#
# - 16.1.10 有用的导数
#
# ### 16.2 一维搜索
#
# - 16.2.1 单峰目标函数
#
# - 16.2.2 黄金分割搜索
#
# - 16.2.3 USPS应用的黄金分割解
#
# - 16.2.4 划界和3点模式
#
# - 16.2.5 寻找3点模式
#
# - 16.2.6 二次拟合搜索
#
# - 16.2.7 USPS应用的二次拟合解
#
# ### 16.3 导数、泰勒级数和多维的局部最优解条件
#
# - 16.3.1 改进搜索范式
#
# - 16.3.2 局部信息和邻域
#
# - 16.3.3 一阶导数和梯度
#
# - 16.3.4 二阶导数和海森矩阵
#
# - 16.3.5 单变量的泰勒级数近似
#
# - 16.3.6 多维变量的泰勒级数近似
#
# - 16.3.7 驻点和局部最优
#
# - 16.3.8 鞍点
#
# - 16.3.9 海森矩阵和局部最优解
#
# ### 16.4 凹凸函数和全局最优
#
# - 16.4.1 凹函数和凸函数定义
#
# - 16.4.2 无约束全局最优解的充分条件
#
# - 16.4.3 凹/凸函数和驻点
#
# - 16.4.4 验证凹函数和凸函数
#
# - 16.4.5 单峰和凹/凸函数
#
# ### 16.5 梯度搜索
#
# - 16.5.1 梯度搜索算法
#
# - 16.5.2 定制计算机应用的梯度搜索
#
# - 16.5.3 最速上升/下降性质
#
# - 16.5.4 梯度搜索的曲折及其较差的收敛性
#
# ### 16.6 牛顿法
#
# - 16.6.1 牛顿步
#
# - 16.6.2 牛顿法
#
# - 16.6.3 定制计算机应用中的牛顿法
#
# - 16.6.4 牛顿法的快速收敛速度
#
# - 16.6.5 梯度搜索和牛顿法的计算权衡
#
# - 16.6.6 牛顿法的初始点
#
# ### 16.7 拟牛顿法和BFGS搜索
#
# - 16.7.1 偏转矩阵
#
# - 16.7.2 拟牛顿方式
#
# - 16.7.3 保证方向改善
#
# - 16.7.4 BFGS公式
#
# - 16.7.5 定制计算机应用的BFGS搜索
#
# - 16.7.6 验证拟牛顿要求
#
# - 16.7.7 用BFGS近似海森矩阵的逆
#
# ### 16.8 无导数优化和Nelder-Mead法
#
# - 16.8.1 Nelder-Mead策略
#
# - 16.8.2 Nelder-Mead方向
#
# - 16.8.3 Nelder-Mead的有限步长
#
# - 16.8.4 Nelder-Mead收缩
#
# - 16.8.5 PERT应用的Nelder-Mead搜索
#
# ## Chapter 17 带约束的非线性规划
#
# ### 17.1 带约束的非线性规划模型
#
# - 17.1.1 Beer Belge选址—分配模型
#
# - 17.1.2 线性约束的非线性规划
#
# - 17.1.3 德士古汽油混合模型
#
# - 17.1.4 工程设计模型
#
# - 17.1.5 氧气系统工程设计模型
#
# ### 17.2 特殊的NLP：凸规划、可分离规划、二次规划和正项几何规划
#
# - 17.2.1 辉瑞最优批量规划模型
#
# - 17.2.2 凸规划
#
# - 17.2.3 凸规划的易处理性
#
# - 17.2.4 可分离规划
#
# - 17.2.5 可分离规划的易处理性
#
# - 17.2.6 二次型投资组合管理模型
#
# - 17.2.7 二次规划定义
#
# - 17.2.8 二次规划的易处理性
#
# - 17.2.9 围堰设计模型
#
# - 17.2.10 正项几何规划
#
# - 17.2.11 正项几何规划的易处理性
#
# ### 17.3 拉格朗日乘子法
#
# - 17.3.1 归纳为等式形式
#
# - 17.3.2 拉格朗日函数和拉格朗日乘子
#
# - 17.3.3 拉格朗日函数的驻点
#
# - 17.3.4 拉格朗日驻点与原始模型
#
# - 17.3.5 拉格朗日乘子法的过程
#
# - 17.3.6 拉格朗日乘子的解释
#
# - 17.3.7 拉格朗日法的局限性
#
# ### 17.4 KARUSH-KUHN-TUCKER最优性条件
#
# - 17.4.1 完全可导的NLP模型
#
# - 17.4.2 互补松弛性条件
#
# - 17.4.3 拉格朗日乘子符号约束
#
# - 17.4.4 KKT条件和KKT点
#
# - 17.4.5 可行改进方向，重温局部最优
#
# - 17.4.6 KKT条件与可行改进方向的存在性
#
# - 17.4.7 KKT最优性条件的充分性
#
# - 17.4.8 KKT最优性条件的必要性
#
# ### 17.5 惩罚与障碍法
#
# - 17.5.1 惩罚函数法
#
# - 17.5.2 服务柜台问题的惩罚方法
#
# - 17.5.3 对带惩罚有约束最优性的总结
#
# - 17.5.4 惩罚函数的可微性
#
# - 17.5.5 精确的惩罚函数
#
# - 17.5.6 管理惩罚因子
#
# - 17.5.7 序列无约束惩罚技术
#
# - 17.5.8 障碍法
#
# - 17.5.9 服务柜台问题的障碍方法
#
# - 17.5.10 障碍法对最优性的收敛
#
# - 17.5.11 管理障碍因子
#
# - 17.5.12 序列无约束障碍技术
#
# ### 17.6 既约梯度法
#
# - 17.6.1 含线性约束NLP的标准形式
#
# - 17.6.2 线性约束的可行方向条件
#
# - 17.6.3 主线性等式的基
#
# - 17.6.4 基变量、非基变量、和超基变量
#
# - 17.6.5 通过求解基变量的主约束维持等式
#
# - 17.6.6 起作用的非负性与退化情况
#
# - 17.6.7 既约梯度
#
# - 17.6.8 既约梯度移动方向
#
# - 17.6.9 既约梯度法中的线搜索
#
# - 17.6.10 既约梯度法中基的变化
#
# - 17.6.11 既约梯度法
#
# - 17.6.12 滤波器调谐问题的既约梯度搜索
#
# - 17.6.13 既约梯度中的主迭代和辅迭代
#
# - 17.6.14 既约梯度的二阶扩展
#
# - 17.6.15 非线性约束的广义既约梯度法
#
# ### 17.7 二次规划求解方法
#
# - 17.7.1 二次规划的一般对称形式
#
# - 17.7.2 滤波器调谐问题的二次规划形式
#
# - 17.7.3 等式约束二次规划和KKT条件
#
# - 17.7.4 KKT条件直接解二次规划
#
# - 17.7.5 二次规划的起作用集方法
#
# - 17.7.6 起作用集方法的步长
#
# - 17.7.7 起作用集方法在KKT点处停止
#
# - 17.7.8 从起作用集中删除约束
#
# - 17.7.9 滤波器调谐问题的起作用约束集
#
# ### 17.8 序列二次规划
#
# - 17.8.1 拉格朗日法和牛顿法背景知识
#
# - 17.8.2 序列二次规划策略
#
# - 17.8.3 算法17E在辉瑞问题应用案例17-9中的应用
#
# - 17.8.4 减少计算的近似值
#
# ### 17.9 可分离规划方法
#
# - 17.9.1 回顾应用案例17-4辉瑞问题
#
# - 17.9.2 可分离函数的分段线性近似
#
# - 17.9.3 可分离规划的线性规划表示
#
# - 17.9.4 可分离规划的线性近似的正确性
#
# - 17.9.5 可分离凸规划
#
# - 17.9.6 可分离非凸规划的求解难点
#
# ### 17.10 正项几何规划方法
#
# - 17.10.1 正项几何规划
#
# - 17.10.2 回顾围堰问题
#
# - 17.10.3 正项几何规划变量的对数变换
#
# - 17.10.4 几何规划变形凸规划
#
# - 17.10.5 求解变换后的几何规划
#
# - 17.10.6 几何规划的对偶问题
#
# - 17.10.7 求解几何规划的难度级别
#
# - 17.10.8 得到原几何规划的解
#
# - 17.10.9 几何规划对偶问题的推演
#
# - 17.10.10 符号几何规划
